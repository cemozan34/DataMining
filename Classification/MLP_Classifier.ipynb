# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import confusion_matrix

# %% [markdown]
# # Readings

# %%
columns = ["trustLevel","totalScanTimeInSeconds","grandTotal","lineItemVoids","scansWithoutRegistration","quantityModifications","scannedLineItemsPerSecond","valuePerSecond","lineItemVoidsPerPosition","fraud"]
df_train = pd.read_csv("train.csv", delimiter="|")
df_test = pd.read_csv("test.csv", delimiter="|")

# %% [markdown]
# # Preparing Data

# %%
# X = np.array(df_train.loc[:,["trustLevel","scansWithoutRegistration","lineItemVoids","quantityModifications"]])
X = np.array(df_train.loc[:,["trustLevel","totalScanTimeInSeconds","grandTotal","lineItemVoids","scansWithoutRegistration","quantityModifications","scannedLineItemsPerSecond","valuePerSecond","lineItemVoidsPerPosition"]
])
y = np.array(df_train["fraud"])

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.3)

# %% [markdown]
# # Training the Model

# %%
model = MLPClassifier(max_iter = 500)
model.fit(X_train,y_train)
pred = model.predict(X_test)

# %%
print("Accuracy score: ")
print(accuracy_score(y_test,pred))
print("Confusion Matrix: ")
print(confusion_matrix(y_test,pred))
# Out:
# Accuracy score:
# 0.9414893617021277
# Confusion Matrix:
# [[531   0]
#  [ 33   0]]

# %%
print('Index\tPredicted\t\tActual')
for i in range(len(pred)):
    if pred[i] != y_test[i]:
        print(i,'\t',pred[i],'\t',y_test[i],'******')
# Out:
# Index	Predicted		Actual
# 33 	 0 	 1 ******
# 58 	 0 	 1 ******
# 70 	 0 	 1 ******
# 74 	 0 	 1 ******
# 84 	 0 	 1 ******
# 85 	 0 	 1 ******
# 88 	 0 	 1 ******
# 97 	 0 	 1 ******
# 136 	 0 	 1 ******
# 140 	 0 	 1 ******
# 143 	 0 	 1 ******
# 149 	 0 	 1 ******
# 178 	 0 	 1 ******
# 184 	 0 	 1 ******
# 186 	 0 	 1 ******
# 266 	 0 	 1 ******
# 308 	 0 	 1 ******
# 310 	 0 	 1 ******
# 371 	 0 	 1 ******
# 377 	 0 	 1 ******
# 380 	 0 	 1 ******
# 382 	 0 	 1 ******
# 401 	 0 	 1 ******
# 415 	 0 	 1 ******
# 429 	 0 	 1 ******
# 444 	 0 	 1 ******
# 450 	 0 	 1 ******
# 489 	 0 	 1 ******
# 513 	 0 	 1 ******
# 533 	 0 	 1 ******
# 536 	 0 	 1 ******
# 549 	 0 	 1 ******
# 558 	 0 	 1 ******

# %% [markdown]
# # Predictions of the Model for the test.csv

# %%
dataToPredict = np.array(df_test.loc[:,["trustLevel","totalScanTimeInSeconds","grandTotal","lineItemVoids","scansWithoutRegistration","quantityModifications","scannedLineItemsPerSecond","valuePerSecond","lineItemVoidsPerPosition"]])
pred = model.predict(dataToPredict)

# %% [markdown]
# # Extracting the Rows which are Associated with Fraud

# %%
new_df = pd.DataFrame(columns=columns[0:9])

# %%
#print("\nPredicted Results")
for i in range(len(pred)):
    if(pred[i] == 1):
        new_df = new_df.append(df_test.iloc[i], ignore_index=True)

# %%
new_df
# Out:
# Empty DataFrame
# Columns: [trustLevel, totalScanTimeInSeconds, grandTotal, lineItemVoids, scansWithoutRegistration, quantityModifications, scannedLineItemsPerSecond, valuePerSecond, lineItemVoidsPerPosition]
# Index: []

# %% [markdown]
# # Exporting frauds to CSV file

# %%
new_df.to_csv('frauds.csv')

# %% [markdown]
# # Preperation for specifying fraud column in the test.csv file

# %%
new_test_dataset = pd.DataFrame(columns=columns)
new_test_dataset = df_test
new_test_dataset
# Out:
#         trustLevel  totalScanTimeInSeconds  grandTotal  lineItemVoids  \
# 0                4                     467       88.48              4
# 1                3                    1004       58.99              7
# 2                1                     162       14.00              4
# 3                5                     532       84.79              9
# 4                5                     890       42.16              4
# ...            ...                     ...         ...            ...
# 498116           4                     783       59.10              2
# 498117           1                     278       98.90              9
# 498118           3                     300        5.41              6
# 498119           2                    1524       33.97              2
# 498120           3                    1456       56.97             11
#
#         scansWithoutRegistration  quantityModifications  \
# 0                              8                      4
# 1                              6                      1
# 2                              5                      4
# 3                              3                      4
# 4                              0                      0
# ...                          ...                    ...
# 498116                         2                      0
# 498117                         5                      4
# 498118                         6                      4
# 498119                         5                      3
# 498120                         7                      2
#
#         scannedLineItemsPerSecond  valuePerSecond  lineItemVoidsPerPosition
# 0                        0.014989        0.189465                  0.571429
# 1                        0.026892        0.058755                  0.259259
# 2                        0.006173        0.086420                  4.000000
# 3                        0.026316        0.159380                  0.642857
# 4                        0.021348        0.047371                  0.210526
# ...                           ...             ...                       ...
# 498116                   0.012771        0.075479                  0.200000
# 498117                   0.050360        0.355755                  0.642857
# 498118                   0.030000        0.018033                  0.666667
# 498119                   0.005906        0.022290                  0.222222
# 498120                   0.019231        0.039128                  0.392857
#
# [498121 rows x 9 columns]

# %%
new_test_dataset["fraud"] = 0
new_test_dataset
# Out:
#         trustLevel  totalScanTimeInSeconds  grandTotal  lineItemVoids  \
# 0                4                     467       88.48              4
# 1                3                    1004       58.99              7
# 2                1                     162       14.00              4
# 3                5                     532       84.79              9
# 4                5                     890       42.16              4
# ...            ...                     ...         ...            ...
# 498116           4                     783       59.10              2
# 498117           1                     278       98.90              9
# 498118           3                     300        5.41              6
# 498119           2                    1524       33.97              2
# 498120           3                    1456       56.97             11
#
#         scansWithoutRegistration  quantityModifications  \
# 0                              8                      4
# 1                              6                      1
# 2                              5                      4
# 3                              3                      4
# 4                              0                      0
# ...                          ...                    ...
# 498116                         2                      0
# 498117                         5                      4
# 498118                         6                      4
# 498119                         5                      3
# 498120                         7                      2
#
#         scannedLineItemsPerSecond  valuePerSecond  lineItemVoidsPerPosition  \
# 0                        0.014989        0.189465                  0.571429
# 1                        0.026892        0.058755                  0.259259
# 2                        0.006173        0.086420                  4.000000
# 3                        0.026316        0.159380                  0.642857
# 4                        0.021348        0.047371                  0.210526
# ...                           ...             ...                       ...
# 498116                   0.012771        0.075479                  0.200000
# 498117                   0.050360        0.355755                  0.642857
# 498118                   0.030000        0.018033                  0.666667
# 498119                   0.005906        0.022290                  0.222222
# 498120                   0.019231        0.039128                  0.392857
#
#         fraud
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ...       ...
# 498116      0
# 498117      0
# 498118      0
# 498119      0
# 498120      0
#
# [498121 rows x 10 columns]

# %% [markdown]
# # Finding frauds in test.csv file

# %%
df_1 = pd.merge(df_test,new_df,  how='left', indicator='is_fraud')
df_1.drop('fraud', inplace=True, axis=1)
df_1['is_fraud'] = np.where(df_1.is_fraud == 'both', 1, 0)

# %%
df_1
# Out:
#         trustLevel  totalScanTimeInSeconds  grandTotal  lineItemVoids  \
# 0                4                     467       88.48              4
# 1                3                    1004       58.99              7
# 2                1                     162       14.00              4
# 3                5                     532       84.79              9
# 4                5                     890       42.16              4
# ...            ...                     ...         ...            ...
# 498116           4                     783       59.10              2
# 498117           1                     278       98.90              9
# 498118           3                     300        5.41              6
# 498119           2                    1524       33.97              2
# 498120           3                    1456       56.97             11
#
#         scansWithoutRegistration  quantityModifications  \
# 0                              8                      4
# 1                              6                      1
# 2                              5                      4
# 3                              3                      4
# 4                              0                      0
# ...                          ...                    ...
# 498116                         2                      0
# 498117                         5                      4
# 498118                         6                      4
# 498119                         5                      3
# 498120                         7                      2
#
#         scannedLineItemsPerSecond  valuePerSecond  lineItemVoidsPerPosition  \
# 0                        0.014989        0.189465                  0.571429
# 1                        0.026892        0.058755                  0.259259
# 2                        0.006173        0.086420                  4.000000
# 3                        0.026316        0.159380                  0.642857
# 4                        0.021348        0.047371                  0.210526
# ...                           ...             ...                       ...
# 498116                   0.012771        0.075479                  0.200000
# 498117                   0.050360        0.355755                  0.642857
# 498118                   0.030000        0.018033                  0.666667
# 498119                   0.005906        0.022290                  0.222222
# 498120                   0.019231        0.039128                  0.392857
#
#         is_fraud
# 0              0
# 1              0
# 2              0
# 3              0
# 4              0
# ...          ...
# 498116         0
# 498117         0
# 498118         0
# 498119         0
# 498120         0
#
# [498121 rows x 10 columns]

# %%
for i in range(len(df_1)):
    if(df_1.iloc[i]["is_fraud"] == 1):
        print(df_1.iloc[i])
# Out:
# trustLevel                     1.000000
# totalScanTimeInSeconds       587.000000
# grandTotal                     3.830000
# lineItemVoids                  0.000000
# scansWithoutRegistration       9.000000
# quantityModifications          0.000000
# scannedLineItemsPerSecond      0.022147
# valuePerSecond                 0.006525
# lineItemVoidsPerPosition       0.000000
# is_fraud                       1.000000
# Name: 108, dtype: float64
# trustLevel                     1.000000
# totalScanTimeInSeconds       583.000000
# grandTotal                    86.070000
# lineItemVoids                  9.000000
# scansWithoutRegistration       9.000000
# quantityModifications          5.000000
# scannedLineItemsPerSecond      0.029160
# valuePerSecond                 0.147633
# lineItemVoidsPerPosition       0.529412
# is_fraud                       1.000000
# Name: 139, dtype: float64
# trustLevel                    1.000000
# totalScanTimeInSeconds       77.000000
# grandTotal                   68.760000
# lineItemVoids                11.000000
# scansWithoutRegistration     10.000000
# quantityModifications         4.000000
# scannedLineItemsPerSecond     0.233766
# valuePerSecond                0.892987
# lineItemVoidsPerPosition      0.611111
# is_fraud                      1.000000
# Name: 159, dtype: float64
# trustLevel                      1.000000
# totalScanTimeInSeconds       1197.000000
# grandTotal                     11.150000
# lineItemVoids                   1.000000
# scansWithoutRegistration        9.000000
# quantityModifications           3.000000
# scannedLineItemsPerSecond       0.010860
# valuePerSecond                  0.009315
# lineItemVoidsPerPosition        0.076923
# is_fraud                        1.000000
# Name: 175, dtype: float64
# trustLevel                      1.000000
# totalScanTimeInSeconds       1332.000000
# grandTotal                      9.190000
# lineItemVoids                   5.000000
# scansWithoutRegistration       10.000000
# quantityModifications           4.000000
# scannedLineItemsPerSecond       0.010511
# valuePerSecond                  0.006899
# lineItemVoidsPerPosition        0.357143
# is_fraud                        1.000000
# Name: 216, dtype: float64
# trustLevel                     1.000000
# totalScanTimeInSeconds       309.000000
# grandTotal                    54.720000
# lineItemVoids                  1.000000
# scansWithoutRegistration       9.000000
# quantityModifications          2.000000
# scannedLineItemsPerSecond      0.067961
# valuePerSecond                 0.177087
# lineItemVoidsPerPosition       0.047619
# is_fraud                       1.000000
# Name: 226, dtype: float64
# trustLevel                     1.000000
# totalScanTimeInSeconds       489.000000
# grandTotal                    67.270000
# lineItemVoids                  0.000000
# scansWithoutRegistration       9.000000
# quantityModifications          0.000000
# scannedLineItemsPerSecond      0.014315
# valuePerSecond                 0.137566
# lineItemVoidsPerPosition       0.000000
# is_fraud                       1.000000
# Name: 237, dtype: float64
# trustLevel                      1.000000
# totalScanTimeInSeconds       1435.000000
# grandTotal                     77.600000
# lineItemVoids                   8.000000
# scansWithoutRegistration       10.000000
# quantityModifications           1.000000
# scannedLineItemsPerSecond       0.011847
# valuePerSecond                  0.054077
# lineItemVoidsPerPosition        0.470588
# is_fraud                        1.000000
# Name: 266, dtype: float64
# trustLevel                      1.00000
# totalScanTimeInSeconds       1439.00000
# grandTotal                     95.65000
# lineItemVoids                   9.00000
# scansWithoutRegistration        8.00000
# quantityModifications           4.00000
# scannedLineItemsPerSecond       0.00417
# valuePerSecond                  0.06647
# lineItemVoidsPerPosition        1.50000
# is_fraud                        1.00000
# Name: 410, dtype: float64
# trustLevel                    1.000000
# totalScanTimeInSeconds       15.000000
# grandTotal                   27.090000
# lineItemVoids                 9.000000
# scansWithoutRegistration     10.000000
# quantityModifications         4.000000
# scannedLineItemsPerSecond     1.933333
# valuePerSecond                1.806000
# lineItemVoidsPerPosition      0.310345
# is_fraud                      1.000000
# Name: 428, dtype: float64
# trustLevel                    1.00000
# totalScanTimeInSeconds       80.00000
# grandTotal                   59.74000
# lineItemVoids                 8.00000
# scansWithoutRegistration      8.00000
# quantityModifications         4.00000
# scannedLineItemsPerSecond     0.20000
# valuePerSecond                0.74675
# lineItemVoidsPerPosition      0.50000
# is_fraud                      1.00000
# Name: 492, dtype: float64
# trustLevel                     1.000000
# totalScanTimeInSeconds       992.000000
# grandTotal                    66.510000
# lineItemVoids                 11.000000
# scansWithoutRegistration       9.000000
# quantityModifications          3.000000
# scannedLineItemsPerSecond      0.002016
# valuePerSecond                 0.067046
# lineItemVoidsPerPosition       5.500000
# is_fraud                       1.000000
# Name: 584, dtype: float64
# trustLevel                      1.000000
# totalScanTimeInSeconds       1678.000000
# grandTotal                     53.530000
# lineItemVoids                  10.000000
# scansWithoutRegistration        9.000000
# quantityModifications           5.000000
# scannedLineItemsPerSecond       0.002980
# valuePerSecond                  0.031901
# lineItemVoidsPerPosition        2.000000
# is_fraud                        1.000000
# Name: 590, dtype: float64
# trustLevel                    1.000000
# totalScanTimeInSeconds       51.000000
# grandTotal                   17.340000
# lineItemVoids                 0.000000
# scansWithoutRegistration      9.000000
# quantityModifications         3.000000
# scannedLineItemsPerSecond     0.411765
# valuePerSecond                0.340000
# lineItemVoidsPerPosition      0.000000
# is_fraud                      1.000000
# Name: 608, dtype: float64
# trustLevel                     1.000000
# totalScanTimeInSeconds       113.000000
# grandTotal                    27.660000
# lineItemVoids                  9.000000
# scansWithoutRegistration      10.000000
# quantityModifications          4.000000
# scannedLineItemsPerSecond      0.097345
# valuePerSecond                 0.244779
# lineItemVoidsPerPosition       0.818182
# is_fraud                       1.000000
# Name: 692, dtype: float64
# trustLevel                     1.000000
# totalScanTimeInSeconds       292.000000
# grandTotal                    81.000000
# lineItemVoids                  8.000000
# scansWithoutRegistration      10.000000
# quantityModifications          4.000000
# scannedLineItemsPerSecond      0.068493
# valuePerSecond                 0.277397
# lineItemVoidsPerPosition       0.400000
# is_fraud                       1.000000
# Name: 741, dtype: float64
# trustLevel                      1.000000
# totalScanTimeInSeconds       1133.000000
# grandTotal                     26.950000
# lineItemVoids                   2.000000
# scansWithoutRegistration       10.000000
# quantityModifications           1.000000
# scannedLineItemsPerSecond       0.023831
# valuePerSecond                  0.023786
# lineItemVoidsPerPosition        0.074074
# is_fraud                        1.000000
# Name: 768, dtype: float64
# trustLevel                     1.000000
# totalScanTimeInSeconds       829.000000
# grandTotal                    87.540000
# lineItemVoids                 11.000000
# scansWithoutRegistration       7.000000
# quantityModifications          5.000000
# scannedLineItemsPerSecond      0.032569
# valuePerSecond                 0.105597
# lineItemVoidsPerPosition       0.407407
# is_fraud                       1.000000
# Name: 806, dtype: float64
# trustLevel                     1.000000
# totalScanTimeInSeconds       780.000000
# grandTotal                    77.380000
# lineItemVoids                  9.000000
# scansWithoutRegistration       9.000000
# quantityModifications          5.000000
# scannedLineItemsPerSecond      0.038462
# valuePerSecond                 0.099205
# lineItemVoidsPerPosition       0.300000
# is_fraud                       1.000000
# Name: 869, dtype: float64
# trustLevel                      1.000000
# totalScanTimeInSeconds       1323.000000
# grandTotal                     38.830000
# lineItemVoids                   8.000000
# scansWithoutRegistration        8.000000
# quantityModifications           4.000000
# scannedLineItemsPerSecond       0.009826
# valuePerSecond                  0.029350
# lineItemVoidsPerPosition        0.615385
# is_fraud                        1.000000
# Name: 978, dtype: float64
# trustLevel                     1.000000
# totalScanTimeInSeconds       212.000000
# grandTotal                     0.960000
# lineItemVoids                  9.000000
# scansWithoutRegistration       8.000000
# quantityModifications          5.000000
# scannedLineItemsPerSecond      0.099057
# valuePerSecond                 0.004528
# lineItemVoidsPerPosition       0.428571
# is_fraud                       1.000000
# Name: 1018, dtype: float64
# trustLevel                     1.000000
# totalScanTimeInSeconds       512.000000
# grandTotal                    55.980000
# lineItemVoids                  3.000000
# scansWithoutRegistration      10.000000
# quantityModifications          2.000000
# scannedLineItemsPerSecond      0.025391
# valuePerSecond                 0.109336
# lineItemVoidsPerPosition       0.230769
# is_fraud                       1.000000
# Name: 1116, dtype: float64
# trustLevel                      1.000000
# totalScanTimeInSeconds       1644.000000
# grandTotal                     74.150000
# lineItemVoids                   5.000000
# scansWithoutRegistration       10.000000
# quantityModifications           4.000000
# scannedLineItemsPerSecond       0.017640
# valuePerSecond                  0.045103
# lineItemVoidsPerPosition        0.172414
# is_fraud                        1.000000
# Name: 1159, dtype: float64
# trustLevel                      1.000000
# totalScanTimeInSeconds       1134.000000
# grandTotal                     77.700000
# lineItemVoids                   8.000000
# scansWithoutRegistration        9.000000
# quantityModifications           2.000000
# scannedLineItemsPerSecond       0.000882
# valuePerSecond                  0.068519
# lineItemVoidsPerPosition        8.000000
# is_fraud                        1.000000
# Name: 1215, dtype: float64
# trustLevel                     1.000000
# totalScanTimeInSeconds       617.000000
# grandTotal                    72.370000
# lineItemVoids                  7.000000
# scansWithoutRegistration      10.000000
# quantityModifications          3.000000
# scannedLineItemsPerSecond      0.034036
# valuePerSecond                 0.117293
# lineItemVoidsPerPosition       0.333333
# is_fraud                       1.000000
# Name: 1241, dtype: float64
# trustLevel                     1.000000
# totalScanTimeInSeconds       548.000000
# grandTotal                    72.340000
# lineItemVoids                  6.000000
# scansWithoutRegistration      10.000000
# quantityModifications          5.000000
# scannedLineItemsPerSecond      0.027372
# valuePerSecond                 0.132007
# lineItemVoidsPerPosition       0.400000
# is_fraud                       1.000000
# Name: 1263, dtype: float64
# trustLevel                     1.000000
# totalScanTimeInSeconds       177.000000
# grandTotal                    86.100000
# lineItemVoids                  3.000000
# scansWithoutRegistration      10.000000
# quantityModifications          0.000000
# scannedLineItemsPerSecond      0.101695
# valuePerSecond                 0.486441
# lineItemVoidsPerPosition       0.166667
# is_fraud                       1.000000
# Name: 1330, dtype: float64
# trustLevel                      1.000000
# totalScanTimeInSeconds       1279.000000
# grandTotal                     36.710000
# lineItemVoids                   2.000000
# scansWithoutRegistration        9.000000
# quantityModifications           1.000000
# scannedLineItemsPerSecond       0.014855
# valuePerSecond                  0.028702
# lineItemVoidsPerPosition        0.105263
# is_fraud                        1.000000
# Name: 1379, dtype: float64
# trustLevel                      1.000000
# totalScanTimeInSeconds       1802.000000
# grandTotal                     17.860000
# lineItemVoids                  10.000000
# scansWithoutRegistration       10.000000
# quantityModifications           2.000000
# scannedLineItemsPerSecond       0.007214
# valuePerSecond                  0.009911
# lineItemVoidsPerPosition        0.769231
# is_fraud                        1.000000
# Name: 1390, dtype: float64
# trustLevel                     1.000000
# totalScanTimeInSeconds       567.000000
# grandTotal                    52.560000
# lineItemVoids                  2.000000
# scansWithoutRegistration      10.000000
# quantityModifications          3.000000
# scannedLineItemsPerSecond      0.045855
# valuePerSecond                 0.092698
# lineItemVoidsPerPosition       0.076923
# is_fraud                       1.000000
# Name: 1459, dtype: float64
# trustLevel                      1.000000
# totalScanTimeInSeconds       1066.000000
# grandTotal                     47.470000
# lineItemVoids                   8.000000
# scansWithoutRegistration       10.000000
# quantityModifications           2.000000
# scannedLineItemsPerSecond       0.019700
# valuePerSecond                  0.044531
# lineItemVoidsPerPosition        0.380952
# is_fraud                        1.000000
# Name: 1498, dtype: float64
# trustLevel                     1.000000
# totalScanTimeInSeconds       464.000000
# grandTotal                    11.970000
# lineItemVoids                  8.000000
# scansWithoutRegistration      10.000000
# quantityModifications          4.000000
# scannedLineItemsPerSecond      0.038793
# valuePerSecond                 0.025797
# lineItemVoidsPerPosition       0.444444
# is_fraud                       1.000000
# Name: 1501, dtype: float64
# trustLevel                      1.000000
# totalScanTimeInSeconds       1416.000000
# grandTotal                     22.070000
# lineItemVoids                   8.000000
# scansWithoutRegistration        9.000000
# quantityModifications           5.000000
# scannedLineItemsPerSecond       0.014831
# valuePerSecond                  0.015586
# lineItemVoidsPerPosition        0.380952
# is_fraud                        1.000000
# Name: 1503, dtype: float64
# trustLevel                      1.000000
# totalScanTimeInSeconds       1001.000000
# grandTotal                     57.640000
# lineItemVoids                   6.000000
# scansWithoutRegistration       10.000000
# quantityModifications           2.000000
# scannedLineItemsPerSecond       0.027972
# valuePerSecond                  0.057582
# lineItemVoidsPerPosition        0.214286
# is_fraud                        1.000000
# Name: 1581, dtype: float64
# trustLevel                     1.000000
# totalScanTimeInSeconds       514.000000
# grandTotal                    29.120000
# lineItemVoids                  7.000000
# scansWithoutRegistration       9.000000
# quantityModifications          3.000000
# scannedLineItemsPerSecond      0.013619
# valuePerSecond                 0.056654
# lineItemVoidsPerPosition       1.000000
# is_fraud                       1.000000
# Name: 1602, dtype: float64
# trustLevel                      1.000000
# totalScanTimeInSeconds       1732.000000
# grandTotal                     66.920000
# lineItemVoids                   2.000000
# scansWithoutRegistration       10.000000
# quantityModifications           3.000000
# scannedLineItemsPerSecond       0.007506
# valuePerSecond                  0.038637
# lineItemVoidsPerPosition        0.153846
# is_fraud                        1.000000
# Name: 1630, dtype: float64
# trustLevel                     1.000000
# totalScanTimeInSeconds       172.000000
# grandTotal                    76.670000
# lineItemVoids                  2.000000
# scansWithoutRegistration      10.000000
# quantityModifications          0.000000
# scannedLineItemsPerSecond      0.110465
# valuePerSecond                 0.445756
# lineItemVoidsPerPosition       0.105263
# is_fraud                       1.000000
# Name: 1643, dtype: float64
# trustLevel                     1.000000
# totalScanTimeInSeconds       896.000000
# grandTotal                     1.340000
# lineItemVoids                  9.000000
# scansWithoutRegistration       8.000000
# quantityModifications          4.000000
# scannedLineItemsPerSecond      0.027902
# valuePerSecond                 0.001496
# lineItemVoidsPerPosition       0.360000
# is_fraud                       1.000000
# Name: 1648, dtype: float64
# trustLevel                      1.000000
# totalScanTimeInSeconds       1671.000000
# grandTotal                     19.430000
# lineItemVoids                   8.000000
# scansWithoutRegistration       10.000000
# quantityModifications           3.000000
# scannedLineItemsPerSecond       0.010772
# valuePerSecond                  0.011628
# lineItemVoidsPerPosition        0.444444
# is_fraud                        1.000000
# Name: 1810, dtype: float64
# trustLevel                      1.000000
# totalScanTimeInSeconds       1046.000000
# grandTotal                     76.110000
# lineItemVoids                   1.000000
# scansWithoutRegistration       10.000000
# quantityModifications           0.000000
# scannedLineItemsPerSecond       0.023901
# valuePerSecond                  0.072763
# lineItemVoidsPerPosition        0.040000
# is_fraud                        1.000000
# Name: 1878, dtype: float64
# trustLevel                      1.000000
# totalScanTimeInSeconds       1092.000000
# grandTotal                     88.150000
# lineItemVoids                   0.000000
# scansWithoutRegistration       10.000000
# quantityModifications           1.000000
# scannedLineItemsPerSecond       0.001832
# valuePerSecond                  0.080723
# lineItemVoidsPerPosition        0.000000
# is_fraud                        1.000000
# Name: 1964, dtype: float64
# trustLevel                      1.000000
# totalScanTimeInSeconds       1191.000000
# grandTotal                     47.540000
# lineItemVoids                   1.000000
# scansWithoutRegistration        9.000000
# quantityModifications           1.000000
# scannedLineItemsPerSecond       0.005877
# valuePerSecond                  0.039916
# lineItemVoidsPerPosition        0.142857
# is_fraud                        1.000000
# Name: 1966, dtype: float64
# trustLevel                     1.000000
# totalScanTimeInSeconds       843.000000
# grandTotal                    53.860000
# lineItemVoids                  0.000000
# scansWithoutRegistration      10.000000
# quantityModifications          1.000000
# scannedLineItemsPerSecond      0.033215
# valuePerSecond                 0.063891
# lineItemVoidsPerPosition       0.000000
# is_fraud                       1.000000
# Name: 1977, dtype: float64
# trustLevel                      1.000000
# totalScanTimeInSeconds       1599.000000
# grandTotal                     17.080000
# lineItemVoids                   8.000000
# scansWithoutRegistration        9.000000
# quantityModifications           5.000000
# scannedLineItemsPerSecond       0.017511
# valuePerSecond                  0.010682
# lineItemVoidsPerPosition        0.285714
# is_fraud                        1.000000
# Name: 1993, dtype: float64
# trustLevel                     1.000000
# totalScanTimeInSeconds       638.000000
# grandTotal                    65.780000
# lineItemVoids                  6.000000
# scansWithoutRegistration      10.000000
# quantityModifications          4.000000
# scannedLineItemsPerSecond      0.026646
# valuePerSecond                 0.103103
# lineItemVoidsPerPosition       0.352941
# is_fraud                       1.000000
# Name: 2027, dtype: float64
# trustLevel                      1.000000
# totalScanTimeInSeconds       1272.000000
# grandTotal                     96.120000
# lineItemVoids                   2.000000
# scansWithoutRegistration       10.000000
# quantityModifications           3.000000
# scannedLineItemsPerSecond       0.007075
# valuePerSecond                  0.075566
# lineItemVoidsPerPosition        0.222222
# is_fraud                        1.000000
# Name: 2036, dtype: float64
# trustLevel                     1.000000
# totalScanTimeInSeconds       893.000000
# grandTotal                    82.410000
# lineItemVoids                 10.000000
# scansWithoutRegistration       7.000000
# quantityModifications          5.000000
# scannedLineItemsPerSecond      0.030235
# valuePerSecond                 0.092284
# lineItemVoidsPerPosition       0.370370
# is_fraud                       1.000000
# Name: 2198, dtype: float64
# trustLevel                      1.000000
# totalScanTimeInSeconds       1733.000000
# grandTotal                     78.280000
# lineItemVoids                   9.000000
# scansWithoutRegistration       10.000000
# quantityModifications           2.000000
# scannedLineItemsPerSecond       0.015003
# valuePerSecond                  0.045170
# lineItemVoidsPerPosition        0.346154
# is_fraud                        1.000000
# Name: 2276, dtype: float64
# trustLevel                      1.000000
# totalScanTimeInSeconds       1629.000000
# grandTotal                     78.530000
# lineItemVoids                  11.000000
# scansWithoutRegistration        9.000000
# quantityModifications           2.000000
# scannedLineItemsPerSecond       0.015347
# valuePerSecond                  0.048207
# lineItemVoidsPerPosition        0.440000
# is_fraud                        1.000000
# Name: 2309, dtype: float64
# trustLevel                     1.000000
# totalScanTimeInSeconds       397.000000
# grandTotal                    11.760000
# lineItemVoids                  5.000000
# scansWithoutRegistration      10.000000
# quantityModifications          2.000000
# scannedLineItemsPerSecond      0.017632
# valuePerSecond                 0.029622
# lineItemVoidsPerPosition       0.714286
# is_fraud                       1.000000
# Name: 2320, dtype: float64
# trustLevel                     1.000000
# totalScanTimeInSeconds       198.000000
# grandTotal                    93.100000
# lineItemVoids                  7.000000
# scansWithoutRegistration       9.000000
# quantityModifications          4.000000
# scannedLineItemsPerSecond      0.020202
# valuePerSecond                 0.470202
# lineItemVoidsPerPosition       1.750000
# is_fraud                       1.000000
# Name: 2352, dtype: float64
# trustLevel                      1.000000
# totalScanTimeInSeconds       1804.000000
# grandTotal                     83.030000
# lineItemVoids                   0.000000
# scansWithoutRegistration       10.000000
# quantityModifications           2.000000
# scannedLineItemsPerSecond       0.007206
# valuePerSecond                  0.046025
# lineItemVoidsPerPosition        0.000000
# is_fraud                        1.000000
# Name: 2363, dtype: float64
# trustLevel                     1.000000
# totalScanTimeInSeconds       776.000000
# grandTotal                    44.710000
# lineItemVoids                 11.000000
# scansWithoutRegistration       9.000000
# quantityModifications          4.000000
# scannedLineItemsPerSecond      0.010309
# valuePerSecond                 0.057616
# lineItemVoidsPerPosition       1.375000
# is_fraud                       1.000000
# Name: 2380, dtype: float64
# trustLevel                     1.000000
# totalScanTimeInSeconds       530.000000
# grandTotal                    75.970000
# lineItemVoids                 11.000000
# scansWithoutRegistration       9.000000
# quantityModifications          3.000000
# scannedLineItemsPerSecond      0.032075
# valuePerSecond                 0.143340
# lineItemVoidsPerPosition       0.647059
# is_fraud                       1.000000
# Name: 2404, dtype: float64
# trustLevel                      1.000000
# totalScanTimeInSeconds       1266.000000
# grandTotal                     72.180000
# lineItemVoids                   8.000000
# scansWithoutRegistration        8.000000
# quantityModifications           5.000000
# scannedLineItemsPerSecond       0.019747
# valuePerSecond                  0.057014
# lineItemVoidsPerPosition        0.320000
# is_fraud                        1.000000
# Name: 2411, dtype: float64
# trustLevel                      1.000000
# totalScanTimeInSeconds       1453.000000
# grandTotal                     85.080000
# lineItemVoids                   9.000000
# scansWithoutRegistration        9.000000
# quantityModifications           3.000000
# scannedLineItemsPerSecond       0.006194
# valuePerSecond                  0.058555
# lineItemVoidsPerPosition        1.000000
# is_fraud                        1.000000
# Name: 2579, dtype: float64
# trustLevel                     1.000000
# totalScanTimeInSeconds       147.000000
# grandTotal                    60.950000
# lineItemVoids                  4.000000
# scansWithoutRegistration      10.000000
# quantityModifications          4.000000
# scannedLineItemsPerSecond      0.170068
# valuePerSecond                 0.414626
# lineItemVoidsPerPosition       0.160000
# is_fraud                       1.000000
# Name: 2680, dtype: float64
# trustLevel                      1.000000
# totalScanTimeInSeconds       1014.000000
# grandTotal                     42.730000
# lineItemVoids                   2.000000
# scansWithoutRegistration       10.000000
# quantityModifications           4.000000
# scannedLineItemsPerSecond       0.028600
# valuePerSecond                  0.042140
# lineItemVoidsPerPosition        0.068966
# is_fraud                        1.000000
# Name: 2742, dtype: float64
# trustLevel                      1.000000
# totalScanTimeInSeconds       1364.000000
# grandTotal                     93.000000
# lineItemVoids                  11.000000
# scansWithoutRegistration        7.000000
# quantityModifications           5.000000
# scannedLineItemsPerSecond       0.010997
# valuePerSecond                  0.068182
# lineItemVoidsPerPosition        0.733333
# is_fraud                        1.000000
# Name: 2899, dtype: float64
# trustLevel                     1.000000
# totalScanTimeInSeconds       929.000000
# grandTotal                     2.260000
# lineItemVoids                  0.000000
# scansWithoutRegistration       9.000000
# quantityModifications          2.000000
# scannedLineItemsPerSecond      0.016146
# valuePerSecond                 0.002433
# lineItemVoidsPerPosition       0.000000
# is_fraud                       1.000000
# Name: 3058, dtype: float64
# trustLevel                      1.000000
# totalScanTimeInSeconds       1661.000000
# grandTotal                     96.720000
# lineItemVoids                   5.000000
# scansWithoutRegistration       10.000000
# quantityModifications           2.000000
# scannedLineItemsPerSecond       0.015653
# valuePerSecond                  0.058230
# lineItemVoidsPerPosition        0.192308
# is_fraud                        1.000000
# Name: 3061, dtype: float64
# trustLevel                      1.000000
# totalScanTimeInSeconds       1288.000000
# grandTotal                     88.130000
# lineItemVoids                   1.000000
# scansWithoutRegistration       10.000000
# quantityModifications           4.000000
# scannedLineItemsPerSecond       0.018634
# valuePerSecond                  0.068424
# lineItemVoidsPerPosition        0.041667
# is_fraud                        1.000000
# Name: 3084, dtype: float64
# trustLevel                     1.000000
# totalScanTimeInSeconds       669.000000
# grandTotal                     2.590000
# lineItemVoids                  7.000000
# scansWithoutRegistration      10.000000
# quantityModifications          2.000000
# scannedLineItemsPerSecond      0.002990
# valuePerSecond                 0.003871
# lineItemVoidsPerPosition       3.500000
# is_fraud                       1.000000
# Name: 3109, dtype: float64
# trustLevel                     1.000000
# totalScanTimeInSeconds       274.000000
# grandTotal                    25.380000
# lineItemVoids                  8.000000
# scansWithoutRegistration      10.000000
# quantityModifications          1.000000
# scannedLineItemsPerSecond      0.083942
# valuePerSecond                 0.092628
# lineItemVoidsPerPosition       0.347826
# is_fraud                       1.000000
# Name: 3143, dtype: float64
# trustLevel                     1.000000
# totalScanTimeInSeconds       833.000000
# grandTotal                    49.350000
# lineItemVoids                 10.000000
# scansWithoutRegistration       7.000000
# quantityModifications          5.000000
# scannedLineItemsPerSecond      0.032413
# valuePerSecond                 0.059244
# lineItemVoidsPerPosition       0.370370
# is_fraud                       1.000000
# Name: 3155, dtype: float64
# trustLevel                     1.000000
# totalScanTimeInSeconds       125.000000
# grandTotal                    39.520000
# lineItemVoids                  4.000000
# scansWithoutRegistration      10.000000
# quantityModifications          2.000000
# scannedLineItemsPerSecond      0.144000
# valuePerSecond                 0.316160
# lineItemVoidsPerPosition       0.222222
# is_fraud                       1.000000
# Name: 3156, dtype: float64
# trustLevel                      1.000000
# totalScanTimeInSeconds       1157.000000
# grandTotal                     73.160000
# lineItemVoids                   9.000000
# scansWithoutRegistration       10.000000
# quantityModifications           3.000000
# scannedLineItemsPerSecond       0.019015
# valuePerSecond                  0.063232
# lineItemVoidsPerPosition        0.409091
# is_fraud                        1.000000
# Name: 3191, dtype: float64
# trustLevel                     1.000000
# totalScanTimeInSeconds       871.000000
# grandTotal                    70.780000
# lineItemVoids                  2.000000
# scansWithoutRegistration      10.000000
# quantityModifications          4.000000
# scannedLineItemsPerSecond      0.009185
# valuePerSecond                 0.081263
# lineItemVoidsPerPosition       0.250000
# is_fraud                       1.000000
# Name: 3201, dtype: float64
# trustLevel                      1.000000
# totalScanTimeInSeconds       1543.000000
# grandTotal                     93.450000
# lineItemVoids                   1.000000
# scansWithoutRegistration       10.000000
# quantityModifications           0.000000
# scannedLineItemsPerSecond       0.011666
# valuePerSecond                  0.060564
# lineItemVoidsPerPosition        0.055556
# is_fraud                        1.000000
# Name: 3272, dtype: float64
# trustLevel                     1.000000
# totalScanTimeInSeconds       128.000000
# grandTotal                    19.920000
# lineItemVoids                  1.000000
# scansWithoutRegistration       9.000000
# quantityModifications          2.000000
# scannedLineItemsPerSecond      0.125000
# valuePerSecond                 0.155625
# lineItemVoidsPerPosition       0.062500
# is_fraud                       1.000000
# Name: 3276, dtype: float64
# trustLevel                     1.000000
# totalScanTimeInSeconds       757.000000
# grandTotal                    68.340000
# lineItemVoids                  5.000000
# scansWithoutRegistration      10.000000
# quantityModifications          5.000000
# scannedLineItemsPerSecond      0.003963
# valuePerSecond                 0.090277
# lineItemVoidsPerPosition       1.666667
# is_fraud                       1.000000
# Name: 3357, dtype: float64
# trustLevel                     1.000000
# totalScanTimeInSeconds       613.000000
# grandTotal                    74.810000
# lineItemVoids                  7.000000
# scansWithoutRegistration       9.000000
# quantityModifications          5.000000
# scannedLineItemsPerSecond      0.014682
# valuePerSecond                 0.122039
# lineItemVoidsPerPosition       0.777778
# is_fraud                       1.000000
# Name: 3367, dtype: float64
# trustLevel                     1.000000
# totalScanTimeInSeconds       798.000000
# grandTotal                     4.750000
# lineItemVoids                  6.000000
# scansWithoutRegistration      10.000000
# quantityModifications          5.000000
# scannedLineItemsPerSecond      0.001253
# valuePerSecond                 0.005952
# lineItemVoidsPerPosition       6.000000
# is_fraud                       1.000000
# Name: 3372, dtype: float64
# trustLevel                      1.000000
# totalScanTimeInSeconds       1119.000000
# grandTotal                     56.240000
# lineItemVoids                   5.000000
# scansWithoutRegistration       10.000000
# quantityModifications           3.000000
# scannedLineItemsPerSecond       0.013405
# valuePerSecond                  0.050259
# lineItemVoidsPerPosition        0.333333
# is_fraud                        1.000000
# Name: 3391, dtype: float64
# trustLevel                     1.000000
# totalScanTimeInSeconds       948.000000
# grandTotal                    76.390000
# lineItemVoids                 11.000000
# scansWithoutRegistration      10.000000
# quantityModifications          0.000000
# scannedLineItemsPerSecond      0.028481
# valuePerSecond                 0.080580
# lineItemVoidsPerPosition       0.407407
# is_fraud                       1.000000
# Name: 3419, dtype: float64
# trustLevel                      1.000000
# totalScanTimeInSeconds       1705.000000
# grandTotal                     12.710000
# lineItemVoids                   9.000000
# scansWithoutRegistration        9.000000
# quantityModifications           3.000000
# scannedLineItemsPerSecond       0.005279
# valuePerSecond                  0.007455
# lineItemVoidsPerPosition        1.000000
# is_fraud                        1.000000
# Name: 3459, dtype: float64
# trustLevel                      1.000000
# totalScanTimeInSeconds       1279.000000
# grandTotal                     45.050000
# lineItemVoids                   2.000000
# scansWithoutRegistration       10.000000
# quantityModifications           3.000000
# scannedLineItemsPerSecond       0.002346
# valuePerSecond                  0.035223
# lineItemVoidsPerPosition        0.666667
# is_fraud                        1.000000
# Name: 3481, dtype: float64
# trustLevel                     1.000000
# totalScanTimeInSeconds       546.000000
# grandTotal                    68.840000
# lineItemVoids                  9.000000
# scansWithoutRegistration      10.000000
# quantityModifications          2.000000
# scannedLineItemsPerSecond      0.045788
# valuePerSecond                 0.126081
# lineItemVoidsPerPosition       0.360000
# is_fraud                       1.000000
# Name: 3500, dtype: float64
# trustLevel                     1.000000
# totalScanTimeInSeconds       654.000000
# grandTotal                    25.760000
# lineItemVoids                  2.000000
# scansWithoutRegistration       9.000000
# quantityModifications          2.000000
# scannedLineItemsPerSecond      0.036697
# valuePerSecond                 0.039388
# lineItemVoidsPerPosition       0.083333
# is_fraud                       1.000000
# Name: 3551, dtype: float64
# trustLevel                      1.000000
# totalScanTimeInSeconds       1460.000000
# grandTotal                     34.990000
# lineItemVoids                   1.000000
# scansWithoutRegistration       10.000000
# quantityModifications           3.000000
# scannedLineItemsPerSecond       0.004110
# valuePerSecond                  0.023966
# lineItemVoidsPerPosition        0.166667
# is_fraud                        1.000000
# Name: 3608, dtype: float64
# trustLevel                      1.000000
# totalScanTimeInSeconds       1785.000000
# grandTotal                     60.390000
# lineItemVoids                   2.000000
# scansWithoutRegistration       10.000000
# quantityModifications           0.000000
# scannedLineItemsPerSecond       0.005602
# valuePerSecond                  0.033832
# lineItemVoidsPerPosition        0.200000
# is_fraud                        1.000000
# Name: 3668, dtype: float64
# trustLevel                     1.000000
# totalScanTimeInSeconds       571.000000
# grandTotal                    21.840000
# lineItemVoids                  8.000000
# scansWithoutRegistration       9.000000
# quantityModifications          4.000000
# scannedLineItemsPerSecond      0.015762
# valuePerSecond                 0.038249
# lineItemVoidsPerPosition       0.888889
# is_fraud                       1.000000
# Name: 3716, dtype: float64
# trustLevel                      1.000000
# totalScanTimeInSeconds       1025.000000
# grandTotal                      3.870000
# lineItemVoids                  11.000000
# scansWithoutRegistration        8.000000
# quantityModifications           3.000000
# scannedLineItemsPerSecond       0.000976
# valuePerSecond                  0.003776
# lineItemVoidsPerPosition       11.000000
# is_fraud                        1.000000
# Name: 3723, dtype: float64
# trustLevel                     1.000000
# totalScanTimeInSeconds       371.000000
# grandTotal                    86.880000
# lineItemVoids                  1.000000
# scansWithoutRegistration      10.000000
# quantityModifications          1.000000
# scannedLineItemsPerSecond      0.051213
# valuePerSecond                 0.234178
# lineItemVoidsPerPosition       0.052632
# is_fraud                       1.000000
# Name: 3726, dtype: float64
# trustLevel                     1.000000
# totalScanTimeInSeconds       949.000000
# grandTotal                    76.880000
# lineItemVoids                  1.000000
# scansWithoutRegistration      10.000000
# quantityModifications          0.000000
# scannedLineItemsPerSecond      0.012645
# valuePerSecond                 0.081012
# lineItemVoidsPerPosition       0.083333
# is_fraud                       1.000000
# Name: 3730, dtype: float64
# trustLevel                      1.000000
# totalScanTimeInSeconds       1791.000000
# grandTotal                     19.190000
# lineItemVoids                   0.000000
# scansWithoutRegistration        9.000000
# quantityModifications           2.000000
# scannedLineItemsPerSecond       0.002233
# valuePerSecond                  0.010715
# lineItemVoidsPerPosition        0.000000
# is_fraud                        1.000000
# Name: 3847, dtype: float64
# trustLevel                      1.000000
# totalScanTimeInSeconds       1054.000000
# grandTotal                     47.180000
# lineItemVoids                   9.000000
# scansWithoutRegistration       10.000000
# quantityModifications           0.000000
# scannedLineItemsPerSecond       0.013283
# valuePerSecond                  0.044763
# lineItemVoidsPerPosition        0.642857
# is_fraud                        1.000000
# Name: 3929, dtype: float64
# trustLevel                     1.000000
# totalScanTimeInSeconds       674.000000
# grandTotal                    54.290000
# lineItemVoids                  6.000000
# scansWithoutRegistration      10.000000
# quantityModifications          5.000000
# scannedLineItemsPerSecond      0.005935
# valuePerSecond                 0.080549
# lineItemVoidsPerPosition       1.500000
# is_fraud                       1.000000
# Name: 3930, dtype: float64
# trustLevel                      1.000000
# totalScanTimeInSeconds       1447.000000
# grandTotal                     22.390000
# lineItemVoids                   8.000000
# scansWithoutRegistration       10.000000
# quantityModifications           3.000000
# scannedLineItemsPerSecond       0.017277
# valuePerSecond                  0.015473
# lineItemVoidsPerPosition        0.320000
# is_fraud                        1.000000
# Name: 3955, dtype: float64
# trustLevel                      1.000000
# totalScanTimeInSeconds       1813.000000
# grandTotal                     79.830000
# lineItemVoids                   8.000000
# scansWithoutRegistration        9.000000
# quantityModifications           4.000000
# scannedLineItemsPerSecond       0.003861
# valuePerSecond                  0.044032
# lineItemVoidsPerPosition        1.142857
# is_fraud                        1.000000
# Name: 3973, dtype: float64
# trustLevel                     1.000000
# totalScanTimeInSeconds       397.000000
# grandTotal                    84.640000
# lineItemVoids                  5.000000
# scansWithoutRegistration      10.000000
# quantityModifications          5.000000
# scannedLineItemsPerSecond      0.022670
# valuePerSecond                 0.213199
# lineItemVoidsPerPosition       0.555556
# is_fraud                       1.000000
# Name: 3976, dtype: float64
# trustLevel                    1.000000
# totalScanTimeInSeconds       40.000000
# grandTotal                    6.550000
# lineItemVoids                 6.000000
# scansWithoutRegistration     10.000000
# quantityModifications         2.000000
# scannedLineItemsPerSecond     0.700000
# valuePerSecond                0.163750
# lineItemVoidsPerPosition      0.214286
# is_fraud                      1.000000
# Name: 3978, dtype: float64
# trustLevel                     1.000000
# totalScanTimeInSeconds       390.000000
# grandTotal                    87.770000
# lineItemVoids                  7.000000
# scansWithoutRegistration      10.000000
# quantityModifications          1.000000
# scannedLineItemsPerSecond      0.051282
# valuePerSecond                 0.225051
# lineItemVoidsPerPosition       0.350000
# is_fraud                       1.000000
# Name: 4025, dtype: float64
# trustLevel                     1.000000
# totalScanTimeInSeconds       693.000000
# grandTotal                    66.120000
# lineItemVoids                  6.000000
# scansWithoutRegistration      10.000000
# quantityModifications          1.000000
# scannedLineItemsPerSecond      0.043290
# valuePerSecond                 0.095411
# lineItemVoidsPerPosition       0.200000
# is_fraud                       1.000000
# Name: 4053, dtype: float64
# trustLevel                      1.000000
# totalScanTimeInSeconds       1440.000000
# grandTotal                     31.520000
# lineItemVoids                  10.000000
# scansWithoutRegistration        8.000000
# quantityModifications           3.000000
# scannedLineItemsPerSecond       0.002083
# valuePerSecond                  0.021889
# lineItemVoidsPerPosition        3.333333
# is_fraud                        1.000000
# Name: 4059, dtype: float64
# trustLevel                     1.000000
# totalScanTimeInSeconds       910.000000
# grandTotal                    67.060000
# lineItemVoids                  2.000000
# scansWithoutRegistration      10.000000
# quantityModifications          2.000000
# scannedLineItemsPerSecond      0.032967
# valuePerSecond                 0.073692
# lineItemVoidsPerPosition       0.066667
# is_fraud                       1.000000
# Name: 4074, dtype: float64
# trustLevel                     1.000000
# totalScanTimeInSeconds       954.000000
# grandTotal                    38.120000
# lineItemVoids                  7.000000
# scansWithoutRegistration      10.000000
# quantityModifications          5.000000
# scannedLineItemsPerSecond      0.012579
# valuePerSecond                 0.039958
# lineItemVoidsPerPosition       0.583333
# is_fraud                       1.000000
# Name: 4181, dtype: float64
# trustLevel                     1.000000
# totalScanTimeInSeconds       535.000000
# grandTotal                    79.860000
# lineItemVoids                  9.000000
# scansWithoutRegistration      10.000000
# quantityModifications          1.000000
# scannedLineItemsPerSecond      0.026168
# valuePerSecond                 0.149271
# lineItemVoidsPerPosition       0.642857
# is_fraud                       1.000000
# Name: 4285, dtype: float64
# trustLevel                      1.000000
# totalScanTimeInSeconds       1088.000000
# grandTotal                     95.760000
# lineItemVoids                   2.000000
# scansWithoutRegistration        9.000000
# quantityModifications           1.000000
# scannedLineItemsPerSecond       0.006434
# valuePerSecond                  0.088015
# lineItemVoidsPerPosition        0.285714
# is_fraud                        1.000000
# Name: 4313, dtype: float64
# trustLevel                     1.000000
# totalScanTimeInSeconds       538.000000
# grandTotal                    88.750000
# lineItemVoids                  9.000000
# scansWithoutRegistration       9.000000
# quantityModifications          3.000000
# scannedLineItemsPerSecond      0.037175
# valuePerSecond                 0.164963
# lineItemVoidsPerPosition       0.450000
# is_fraud                       1.000000
# Name: 4325, dtype: float64
# trustLevel                     1.000000
# totalScanTimeInSeconds       138.000000
# grandTotal                    91.940000
# lineItemVoids                  7.000000
# scansWithoutRegistration       8.000000
# quantityModifications          5.000000
# scannedLineItemsPerSecond      0.195652
# valuePerSecond                 0.666232
# lineItemVoidsPerPosition       0.259259
# is_fraud                       1.000000
# Name: 4326, dtype: float64
# trustLevel                     1.000000
# totalScanTimeInSeconds       900.000000
# grandTotal                    60.640000
# lineItemVoids                  2.000000
# scansWithoutRegistration      10.000000
# quantityModifications          2.000000
# scannedLineItemsPerSecond      0.022222
# valuePerSecond                 0.067378
# lineItemVoidsPerPosition       0.100000
# is_fraud                       1.000000
# Name: 4350, dtype: float64
# trustLevel                      1.000000
# totalScanTimeInSeconds       1482.000000
# grandTotal                     79.540000
# lineItemVoids                  11.000000
# scansWithoutRegistration       10.000000
# quantityModifications           1.000000
# scannedLineItemsPerSecond       0.006748
# valuePerSecond                  0.053671
# lineItemVoidsPerPosition        1.100000
# is_fraud                        1.000000
# Name: 4367, dtype: float64
# trustLevel                     1.000000
# totalScanTimeInSeconds       582.000000
# grandTotal                    81.200000
# lineItemVoids                  6.000000
# scansWithoutRegistration      10.000000
# quantityModifications          1.000000
# scannedLineItemsPerSecond      0.027491
# valuePerSecond                 0.139519
# lineItemVoidsPerPosition       0.375000
# is_fraud                       1.000000
# Name: 4420, dtype: float64
# trustLevel                     1.000000
# totalScanTimeInSeconds       802.000000
# grandTotal                    46.950000
# lineItemVoids                  9.000000
# scansWithoutRegistration       9.000000
# quantityModifications          4.000000
# scannedLineItemsPerSecond      0.037406
# valuePerSecond                 0.058541
# lineItemVoidsPerPosition       0.300000
# is_fraud                       1.000000
# Name: 4478, dtype: float64
# trustLevel                      1.000000
# totalScanTimeInSeconds       1210.000000
# grandTotal                     72.910000
# lineItemVoids                   1.000000
# scansWithoutRegistration        9.000000
# quantityModifications           3.000000
# scannedLineItemsPerSecond       0.004132
# valuePerSecond                  0.060256
# lineItemVoidsPerPosition        0.200000
# is_fraud                        1.000000
# Name: 4558, dtype: float64
# trustLevel                      1.000000
# totalScanTimeInSeconds       1445.000000
# grandTotal                     66.850000
# lineItemVoids                   7.000000
# scansWithoutRegistration        9.000000
# quantityModifications           3.000000
# scannedLineItemsPerSecond       0.012457
# valuePerSecond                  0.046263
# lineItemVoidsPerPosition        0.388889
# is_fraud                        1.000000
# Name: 4580, dtype: float64
# trustLevel                     1.000000
# totalScanTimeInSeconds       476.000000
# grandTotal                    85.070000
# lineItemVoids                  4.000000
# scansWithoutRegistration      10.000000
# quantityModifications          3.000000
# scannedLineItemsPerSecond      0.054622
# valuePerSecond                 0.178718
# lineItemVoidsPerPosition       0.153846
# is_fraud                       1.000000
# Name: 4628, dtype: float64
# trustLevel                    1.000000
# totalScanTimeInSeconds       75.000000
# grandTotal                   10.430000
# lineItemVoids                11.000000
# scansWithoutRegistration      9.000000
# quantityModifications         4.000000
# scannedLineItemsPerSecond     0.386667
# valuePerSecond                0.139067
# lineItemVoidsPerPosition      0.379310
# is_fraud                      1.000000
# Name: 4694, dtype: float64
# trustLevel                      1.000000
# totalScanTimeInSeconds       1768.000000
# grandTotal                     39.810000
# lineItemVoids                   4.000000
# scansWithoutRegistration       10.000000
# quantityModifications           4.000000
# scannedLineItemsPerSecond       0.005656
# valuePerSecond                  0.022517
# lineItemVoidsPerPosition        0.400000
# is_fraud                        1.000000
# Name: 4902, dtype: float64
# trustLevel                     1.000000
# totalScanTimeInSeconds       533.000000
# grandTotal                    75.910000
# lineItemVoids                 10.000000
# scansWithoutRegistration      10.000000
# quantityModifications          0.000000
# scannedLineItemsPerSecond      0.043152
# valuePerSecond                 0.142420
# lineItemVoidsPerPosition       0.434783
# is_fraud                       1.000000
# Name: 4906, dtype: float64
# trustLevel                     1.000000
# totalScanTimeInSeconds       872.000000
# grandTotal                    58.170000
# lineItemVoids                 11.000000
# scansWithoutRegistration       9.000000
# ...
# totalScanTimeInSeconds       463.000000
# grandTotal                    61.420000
# lineItemVoids                 10.000000
# scansWithoutRegistration       9.000000
# quantityModifications          3.000000
# scannedLineItemsPerSecond      0.025918
# valuePerSecond                 0.132657
# lineItemVoidsPerPosition       0.833333
# is_fraud                       1.000000
# Name: 14024, dtype: float64
# trustLevel                     1.000000
# totalScanTimeInSeconds       948.000000
# grandTotal                    65.590000
# lineItemVoids                  5.000000
# scansWithoutRegistration      10.000000
# quantityModifications          4.000000
# scannedLineItemsPerSecond      0.011603
# valuePerSecond                 0.069188
# lineItemVoidsPerPosition       0.454545
# is_fraud                       1.000000
# Name: 14049, dtype: float64
# trustLevel                      1.000000
# totalScanTimeInSeconds       1745.000000
# grandTotal                     98.170000
# lineItemVoids                   9.000000
# scansWithoutRegistration        8.000000
# quantityModifications           5.000000
# scannedLineItemsPerSecond       0.006304
# valuePerSecond                  0.056258
# lineItemVoidsPerPosition        0.818182
# is_fraud                        1.000000
# Name: 14095, dtype: float64
# trustLevel                     1.000000
# totalScanTimeInSeconds       334.000000
# grandTotal                    79.150000
# lineItemVoids                  6.000000
# scansWithoutRegistration      10.000000
# quantityModifications          1.000000
# scannedLineItemsPerSecond      0.041916
# valuePerSecond                 0.236976
# lineItemVoidsPerPosition       0.428571
# is_fraud                       1.000000
# Name: 14116, dtype: float64
# trustLevel                      1.000000
# totalScanTimeInSeconds       1577.000000
# grandTotal                     22.000000
# lineItemVoids                   1.000000
# scansWithoutRegistration       10.000000
# quantityModifications           4.000000
# scannedLineItemsPerSecond       0.015853
# valuePerSecond                  0.013951
# lineItemVoidsPerPosition        0.040000
# is_fraud                        1.000000
# Name: 14188, dtype: float64
# trustLevel                     1.000000
# totalScanTimeInSeconds       314.000000
# grandTotal                     6.630000
# lineItemVoids                  7.000000
# scansWithoutRegistration       9.000000
# quantityModifications          4.000000
# scannedLineItemsPerSecond      0.066879
# valuePerSecond                 0.021115
# lineItemVoidsPerPosition       0.333333
# is_fraud                       1.000000
# Name: 14196, dtype: float64
# trustLevel                     1.000000
# totalScanTimeInSeconds       251.000000
# grandTotal                    74.870000
# lineItemVoids                  8.000000
# scansWithoutRegistration       8.000000
# quantityModifications          5.000000
# scannedLineItemsPerSecond      0.035857
# valuePerSecond                 0.298287
# lineItemVoidsPerPosition       0.888889
# is_fraud                       1.000000
# Name: 14227, dtype: float64
# trustLevel                     1.000000
# totalScanTimeInSeconds       225.000000
# grandTotal                    47.420000
# lineItemVoids                 11.000000
# scansWithoutRegistration      10.000000
# quantityModifications          2.000000
# scannedLineItemsPerSecond      0.097778
# valuePerSecond                 0.210756
# lineItemVoidsPerPosition       0.500000
# is_fraud                       1.000000
# Name: 14232, dtype: float64
# trustLevel                     1.000000
# totalScanTimeInSeconds       660.000000
# grandTotal                    63.590000
# lineItemVoids                  1.000000
# scansWithoutRegistration       9.000000
# quantityModifications          2.000000
# scannedLineItemsPerSecond      0.024242
# valuePerSecond                 0.096348
# lineItemVoidsPerPosition       0.062500
# is_fraud                       1.000000
# Name: 14235, dtype: float64
# trustLevel                     1.000000
# totalScanTimeInSeconds       196.000000
# grandTotal                    10.420000
# lineItemVoids                  8.000000
# scansWithoutRegistration      10.000000
# quantityModifications          1.000000
# scannedLineItemsPerSecond      0.081633
# valuePerSecond                 0.053163
# lineItemVoidsPerPosition       0.500000
# is_fraud                       1.000000
# Name: 14328, dtype: float64
# trustLevel                     1.000000
# totalScanTimeInSeconds       299.000000
# grandTotal                    88.630000
# lineItemVoids                 11.000000
# scansWithoutRegistration       7.000000
# quantityModifications          5.000000
# scannedLineItemsPerSecond      0.023411
# valuePerSecond                 0.296421
# lineItemVoidsPerPosition       1.571429
# is_fraud                       1.000000
# Name: 14353, dtype: float64
# trustLevel                      1.000000
# totalScanTimeInSeconds       1147.000000
# grandTotal                     86.900000
# lineItemVoids                  11.000000
# scansWithoutRegistration        8.000000
# quantityModifications           3.000000
# scannedLineItemsPerSecond       0.023540
# valuePerSecond                  0.075763
# lineItemVoidsPerPosition        0.407407
# is_fraud                        1.000000
# Name: 14420, dtype: float64
# trustLevel                      1.000000
# totalScanTimeInSeconds       1033.000000
# grandTotal                     47.110000
# lineItemVoids                   7.000000
# scansWithoutRegistration        8.000000
# quantityModifications           5.000000
# scannedLineItemsPerSecond       0.006776
# valuePerSecond                  0.045605
# lineItemVoidsPerPosition        1.000000
# is_fraud                        1.000000
# Name: 14483, dtype: float64
# trustLevel                     1.000000
# totalScanTimeInSeconds       431.000000
# grandTotal                     6.390000
# lineItemVoids                  6.000000
# scansWithoutRegistration      10.000000
# quantityModifications          3.000000
# scannedLineItemsPerSecond      0.002320
# valuePerSecond                 0.014826
# lineItemVoidsPerPosition       6.000000
# is_fraud                       1.000000
# Name: 14505, dtype: float64
# trustLevel                      1.000000
# totalScanTimeInSeconds       1304.000000
# grandTotal                     44.850000
# lineItemVoids                   4.000000
# scansWithoutRegistration       10.000000
# quantityModifications           2.000000
# scannedLineItemsPerSecond       0.013037
# valuePerSecond                  0.034394
# lineItemVoidsPerPosition        0.235294
# is_fraud                        1.000000
# Name: 14531, dtype: float64
# trustLevel                     1.000000
# totalScanTimeInSeconds       895.000000
# grandTotal                     5.910000
# lineItemVoids                  5.000000
# scansWithoutRegistration      10.000000
# quantityModifications          3.000000
# scannedLineItemsPerSecond      0.020112
# valuePerSecond                 0.006603
# lineItemVoidsPerPosition       0.277778
# is_fraud                       1.000000
# Name: 14566, dtype: float64
# trustLevel                     1.000000
# totalScanTimeInSeconds       808.000000
# grandTotal                    23.940000
# lineItemVoids                 11.000000
# scansWithoutRegistration       8.000000
# quantityModifications          5.000000
# scannedLineItemsPerSecond      0.014851
# valuePerSecond                 0.029629
# lineItemVoidsPerPosition       0.916667
# is_fraud                       1.000000
# Name: 14589, dtype: float64
# trustLevel                      1.000000
# totalScanTimeInSeconds       1825.000000
# grandTotal                     69.250000
# lineItemVoids                  11.000000
# scansWithoutRegistration       10.000000
# quantityModifications           5.000000
# scannedLineItemsPerSecond       0.000548
# valuePerSecond                  0.037945
# lineItemVoidsPerPosition       11.000000
# is_fraud                        1.000000
# Name: 14595, dtype: float64
# trustLevel                    1.000000
# totalScanTimeInSeconds       92.000000
# grandTotal                   49.050000
# lineItemVoids                 7.000000
# scansWithoutRegistration      8.000000
# quantityModifications         5.000000
# scannedLineItemsPerSecond     0.130435
# valuePerSecond                0.533152
# lineItemVoidsPerPosition      0.583333
# is_fraud                      1.000000
# Name: 14608, dtype: float64
# trustLevel                     1.000000
# totalScanTimeInSeconds       514.000000
# grandTotal                    75.110000
# lineItemVoids                  0.000000
# scansWithoutRegistration      10.000000
# quantityModifications          0.000000
# scannedLineItemsPerSecond      0.054475
# valuePerSecond                 0.146128
# lineItemVoidsPerPosition       0.000000
# is_fraud                       1.000000
# Name: 14630, dtype: float64
# trustLevel                      1.000000
# totalScanTimeInSeconds       1585.000000
# grandTotal                     47.920000
# lineItemVoids                   8.000000
# scansWithoutRegistration       10.000000
# quantityModifications           5.000000
# scannedLineItemsPerSecond       0.003785
# valuePerSecond                  0.030233
# lineItemVoidsPerPosition        1.333333
# is_fraud                        1.000000
# Name: 14687, dtype: float64
# trustLevel                      1.000000
# totalScanTimeInSeconds       1367.000000
# grandTotal                     46.600000
# lineItemVoids                  10.000000
# scansWithoutRegistration        9.000000
# quantityModifications           4.000000
# scannedLineItemsPerSecond       0.009510
# valuePerSecond                  0.034089
# lineItemVoidsPerPosition        0.769231
# is_fraud                        1.000000
# Name: 14740, dtype: float64
# trustLevel                      1.000000
# totalScanTimeInSeconds       1016.000000
# grandTotal                     29.570000
# lineItemVoids                   9.000000
# scansWithoutRegistration       10.000000
# quantityModifications           0.000000
# scannedLineItemsPerSecond       0.007874
# valuePerSecond                  0.029104
# lineItemVoidsPerPosition        1.125000
# is_fraud                        1.000000
# Name: 14741, dtype: float64
# trustLevel                      1.000000
# totalScanTimeInSeconds       1276.000000
# grandTotal                     37.260000
# lineItemVoids                   1.000000
# scansWithoutRegistration       10.000000
# quantityModifications           4.000000
# scannedLineItemsPerSecond       0.009404
# valuePerSecond                  0.029201
# lineItemVoidsPerPosition        0.083333
# is_fraud                        1.000000
# Name: 14775, dtype: float64
# trustLevel                     1.000000
# totalScanTimeInSeconds       842.000000
# grandTotal                    32.270000
# lineItemVoids                  4.000000
# scansWithoutRegistration      10.000000
# quantityModifications          4.000000
# scannedLineItemsPerSecond      0.033254
# valuePerSecond                 0.038325
# lineItemVoidsPerPosition       0.142857
# is_fraud                       1.000000
# Name: 14776, dtype: float64
# trustLevel                     1.000000
# totalScanTimeInSeconds       354.000000
# grandTotal                     7.230000
# lineItemVoids                  8.000000
# scansWithoutRegistration      10.000000
# quantityModifications          1.000000
# scannedLineItemsPerSecond      0.053672
# valuePerSecond                 0.020424
# lineItemVoidsPerPosition       0.421053
# is_fraud                       1.000000
# Name: 14795, dtype: float64
# trustLevel                     1.000000
# totalScanTimeInSeconds       154.000000
# grandTotal                    14.400000
# lineItemVoids                  8.000000
# scansWithoutRegistration       9.000000
# quantityModifications          4.000000
# scannedLineItemsPerSecond      0.149351
# valuePerSecond                 0.093506
# lineItemVoidsPerPosition       0.347826
# is_fraud                       1.000000
# Name: 14817, dtype: float64
# trustLevel                     1.000000
# totalScanTimeInSeconds       715.000000
# grandTotal                    64.940000
# lineItemVoids                 10.000000
# scansWithoutRegistration       7.000000
# quantityModifications          5.000000
# scannedLineItemsPerSecond      0.037762
# valuePerSecond                 0.090825
# lineItemVoidsPerPosition       0.370370
# is_fraud                       1.000000
# Name: 14836, dtype: float64
# trustLevel                     1.000000
# totalScanTimeInSeconds       191.000000
# grandTotal                    80.970000
# lineItemVoids                 10.000000
# scansWithoutRegistration       9.000000
# quantityModifications          3.000000
# scannedLineItemsPerSecond      0.047120
# valuePerSecond                 0.423927
# lineItemVoidsPerPosition       1.111111
# is_fraud                       1.000000
# Name: 14975, dtype: float64
# trustLevel                      1.000000
# totalScanTimeInSeconds       1596.000000
# grandTotal                     31.960000
# lineItemVoids                   1.000000
# scansWithoutRegistration        9.000000
# quantityModifications           0.000000
# scannedLineItemsPerSecond       0.001880
# valuePerSecond                  0.020025
# lineItemVoidsPerPosition        0.333333
# is_fraud                        1.000000
# Name: 14993, dtype: float64
# trustLevel                      1.000000
# totalScanTimeInSeconds       1080.000000
# grandTotal                     80.340000
# lineItemVoids                  10.000000
# scansWithoutRegistration       10.000000
# quantityModifications           5.000000
# scannedLineItemsPerSecond       0.003704
# valuePerSecond                  0.074389
# lineItemVoidsPerPosition        2.500000
# is_fraud                        1.000000
# Name: 15000, dtype: float64
# trustLevel                      1.000000
# totalScanTimeInSeconds       1751.000000
# grandTotal                     69.180000
# lineItemVoids                   7.000000
# scansWithoutRegistration        9.000000
# quantityModifications           5.000000
# scannedLineItemsPerSecond       0.015991
# valuePerSecond                  0.039509
# lineItemVoidsPerPosition        0.250000
# is_fraud                        1.000000
# Name: 15047, dtype: float64
# trustLevel                     1.000000
# totalScanTimeInSeconds       725.000000
# grandTotal                    44.000000
# lineItemVoids                  7.000000
# scansWithoutRegistration       9.000000
# quantityModifications          3.000000
# scannedLineItemsPerSecond      0.037241
# valuePerSecond                 0.060690
# lineItemVoidsPerPosition       0.259259
# is_fraud                       1.000000
# Name: 15102, dtype: float64
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9160/3817550547.py in <module>
#       1 for i in range(len(df_1)):
#       2     if(df_1.iloc[i]["is_fraud"] == 1):
# ----> 3         print(df_1.iloc[i])
#
# ~\Anaconda3\lib\site-packages\ipykernel\iostream.py in write(self, string)
#     527             is_child = (not self._is_master_process())
#     528             # only touch the buffer in the IO thread to avoid races
# --> 529             self.pub_thread.schedule(lambda: self._buffer.write(string))
#     530             if is_child:
#     531                 # mp.Pool cannot be trusted to flush promptly (or ever),
#
# ~\Anaconda3\lib\site-packages\ipykernel\iostream.py in schedule(self, f)
#     212             self._events.append(f)
#     213             # wake event thread (message content is ignored)
# --> 214             self._event_pipe.send(b'')
#     215         else:
#     216             f()
#
# ~\Anaconda3\lib\site-packages\zmq\sugar\socket.py in send(self, data, flags, copy, track, routing_id, group)
#     398                                  copy_threshold=self.copy_threshold)
#     399             data.group = group
# --> 400         return super(Socket, self).send(data, flags=flags, copy=copy, track=track)
#     401
#     402     def send_multipart(self, msg_parts, flags=0, copy=True, track=False, **kwargs):
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._send_copy()
#
# ~\Anaconda3\lib\site-packages\zmq\backend\cython\checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:

# %% [markdown]
# # Exporting the New test.csv File as test_with_frauds.csv

# %%
df_1.to_csv('test_with_frauds.csv')
